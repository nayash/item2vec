# %%
from constants import *
import pandas as pd
import os
from pathlib import Path

# downloaded from https://grouplens.org/datasets/movielens/ -- I'm using 25M dataset
rating_csv_path = f'{data_path}/ratings.csv'
rating_csv_path = Path(rating_csv_path).resolve()#.parents[0].absolute

# %%
df_rating = pd.read_csv(rating_csv_path)
df_rating.dtypes
# Out:
# userId         int64
# movieId        int64
# rating       float64
# timestamp      int64
# dtype: object

# %%
df_rating.sample(10)
# Out:
#           userId  movieId  rating   timestamp
# 459054      3150    36401     2.0  1216309530
# 17430804  112941      362     2.0   849887784
# 13163864   85232     4226     3.5  1456668372
# 16435342  106614     2424     1.0  1237759280
# 10390703   67415    49272     3.5  1558286496
# 5482479    35538     2692     4.0   942335764
# 3512962    23169     4317     2.0  1110381616
# 17798245  115367      954     3.5  1066712372
# 18627613  120708    99636     3.5  1462188548
# 22289104  144959     3996     3.0  1005266539

# %%
f'number of unique users = {len(df_rating["userId"].unique())}'
# Out:
# 'number of unique users = 162541'

# %% [markdown]
# Find the movies liked by each user. For example if user 1 has liked 3 movies 'a', 'b', 'c' then together the list of movies would act like a sentence in conventional NLP problem and each movie would be words. So the more frequently 2 movies appear in each other's vicinity the more similar they must be. In item2vec case the "vicinity" would be the whole sentence/list of movies liked.

# %%
df_user_likes = df_rating[df_rating['rating']>=4]
df_user_likes = df_user_likes['movieId'].groupby(df_user_likes['userId']).agg(list).reset_index()
df_user_likes
# Out:
#         userId                                            movieId
# 0            1  [296, 307, 665, 1088, 1237, 1250, 1653, 2351, ...
# 1            2  [110, 150, 151, 236, 260, 318, 333, 349, 356, ...
# 2            3  [1, 29, 32, 50, 111, 172, 214, 260, 293, 296, ...
# 3            4  [296, 541, 589, 924, 1036, 1136, 1196, 1197, 1...
# 4            5  [1, 19, 32, 36, 47, 50, 88, 104, 141, 147, 150...
# ...        ...                                                ...
# 162337  162537  [31, 88, 207, 216, 282, 318, 356, 361, 466, 52...
# 162338  162538  [17, 39, 47, 48, 111, 215, 337, 356, 500, 527,...
# 162339  162539  [110, 161, 356, 480, 541, 608, 750, 780, 912, ...
# 162340  162540  [32, 1721, 2205, 3005, 3980, 4167, 4306, 4310,...
# 162341  162541  [29, 32, 47, 50, 260, 293, 318, 345, 527, 541,...
#
# [162342 rows x 2 columns]

# %% [markdown]
# Same as above for movies disliked.

# %%
df_user_dislikes = df_rating[df_rating['rating']<4]
df_user_dislikes = df_user_dislikes['movieId'].groupby(df_user_dislikes['userId']).agg(list).reset_index()
df_user_dislikes
# Out:
#         userId                                            movieId
# 0            1  [306, 899, 1175, 1217, 1260, 2011, 2012, 2068,...
# 1            2  [1, 62, 261, 266, 380, 480, 524, 553, 588, 653...
# 2            3  [173, 442, 480, 780, 1127, 1198, 1270, 1320, 1...
# 3            4  [1, 260, 780, 1080, 1200, 1201, 1210, 1214, 12...
# 4            5  [39, 95, 113, 122, 153, 191, 218, 219, 235, 23...
# ...        ...                                                ...
# 161506  162537  [48, 376, 505, 551, 700, 1005, 1556, 1566, 158...
# 161507  162538  [1, 260, 296, 551, 597, 902, 1183, 1230, 1244,...
# 161508  162539                            [466, 1748, 4370, 4446]
# 161509  162540  [169, 519, 1125, 1367, 2384, 2986, 3159, 3869,...
# 161510  162541  [105, 141, 145, 150, 153, 208, 261, 296, 344, ...
#
# [161511 rows x 2 columns]

# %% [markdown]
# combine both liked and disliked into a single list which would be our corpus for training.

# %%
movie_groups = list(df_user_likes['movieId']) + list(df_user_dislikes['movieId'])
len(movie_groups)
# Out:
# 323853

# %% [markdown]
# Next step is to train a Word2Vec model. On my system using skipgram took 1 hour 45 mins to train for 5 epochs while CBOW took only 16 mins to train. Also CBOW seems to recommend more relevant items.
#
# Setting logging to Info as Word2Vec doesn't print any progress log without it.
#
# Also training models for more than 5 epochs doesn't seem to have any improvement on model outputs for neither SG nor CBOW. So clearly CBOW won!

# %%
from gensim.models import Word2Vec
import datetime

# Word2Vec doesn't have "overfitting concept. So using more epochs."

import logging
logging.basicConfig()
logging.getLogger().setLevel(logging.INFO)

start_time = datetime.datetime.now()
max_window = max([len(group) for group in movie_groups])
prev_model = None # 'movie_rec_2023-05-20 03:12:43.294816'
use_skipgram = False

if prev_model:
  model = Word2Vec.load(f'{output_path}/{prev_model}')
  print(f'resuming training: worker={model.workers}')
  model.train(movie_groups, epochs=10, total_examples=model.corpus_count)
else:
  model = Word2Vec(movie_groups, epochs=5, window=max_window,
                  min_count=10, workers=7,
                    sg=1 if use_skipgram else 0, hs=0, negative=5)

print(f'training time = {datetime.datetime.now()-start_time}')
model.save(f'{output_path}/movie_rec_{datetime.datetime.now()}_cbow_epoch5')
# Out:
# INFO:gensim.models.word2vec:collecting all words and their counts
# INFO:gensim.models.word2vec:PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #10000, processed 752872 words, keeping 16469 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #20000, processed 1517195 words, keeping 21102 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #30000, processed 2293768 words, keeping 24467 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #40000, processed 3069414 words, keeping 26783 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #50000, processed 3832289 words, keeping 28567 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #60000, processed 4587089 words, keeping 29782 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #70000, processed 5364753 words, keeping 30935 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #80000, processed 6147106 words, keeping 35064 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #90000, processed 6910308 words, keeping 35946 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #100000, processed 7682994 words, keeping 36810 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #110000, processed 8452077 words, keeping 37441 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #120000, processed 9231617 words, keeping 38478 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #130000, processed 9974483 words, keeping 39117 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #140000, processed 10734120 words, keeping 39703 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #150000, processed 11513140 words, keeping 40225 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #160000, processed 12278708 words, keeping 40731 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #170000, processed 13023664 words, keeping 42121 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #180000, processed 13785383 words, keeping 43861 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #190000, processed 14565253 words, keeping 45456 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #200000, processed 15400678 words, keeping 48060 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #210000, processed 16173293 words, keeping 49357 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #220000, processed 16922237 words, keeping 50020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #230000, processed 17726418 words, keeping 50916 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #240000, processed 18509865 words, keeping 55171 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #250000, processed 19301849 words, keeping 56035 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #260000, processed 20077088 words, keeping 56440 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #270000, processed 20841210 words, keeping 56873 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #280000, processed 21632796 words, keeping 57405 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #290000, processed 22374272 words, keeping 57869 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #300000, processed 23159709 words, keeping 58267 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #310000, processed 23933332 words, keeping 58639 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #320000, processed 24715136 words, keeping 58937 word types
# INFO:gensim.models.word2vec:collected 59047 word types from a corpus of 25000095 raw words and 323853 sentences
# INFO:gensim.models.word2vec:Creating a fresh vocabulary
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'effective_min_count=10 retains 24330 unique words (41.20% of original 59047, drops 34717)', 'datetime': '2023-05-20T23:27:57.931301', 'gensim': '4.3.1', 'python': '3.8.13 (default, Mar 28 2022, 11:38:47) \n[GCC 7.5.0]', 'platform': 'Linux-5.19.0-41-generic-x86_64-with-glibc2.17', 'event': 'prepare_vocab'}
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'effective_min_count=10 leaves 24890583 word corpus (99.56% of original 25000095, drops 109512)', 'datetime': '2023-05-20T23:27:57.931970', 'gensim': '4.3.1', 'python': '3.8.13 (default, Mar 28 2022, 11:38:47) \n[GCC 7.5.0]', 'platform': 'Linux-5.19.0-41-generic-x86_64-with-glibc2.17', 'event': 'prepare_vocab'}
# INFO:gensim.models.word2vec:deleting the raw counts dictionary of 59047 items
# INFO:gensim.models.word2vec:sample=0.001 downsamples 6 most-common words
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 24843209.840730153 word corpus (99.8%% of prior 24890583)', 'datetime': '2023-05-20T23:27:58.047286', 'gensim': '4.3.1', 'python': '3.8.13 (default, Mar 28 2022, 11:38:47) \n[GCC 7.5.0]', 'platform': 'Linux-5.19.0-41-generic-x86_64-with-glibc2.17', 'event': 'prepare_vocab'}
# INFO:gensim.models.word2vec:estimated required memory for 24330 words and 100 dimensions: 31629000 bytes
# INFO:gensim.models.word2vec:resetting layer weights
# INFO:gensim.utils:Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-05-20T23:27:58.231086', 'gensim': '4.3.1', 'python': '3.8.13 (default, Mar 28 2022, 11:38:47) \n[GCC 7.5.0]', 'platform': 'Linux-5.19.0-41-generic-x86_64-with-glibc2.17', 'event': 'build_vocab'}
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'training model with 7 workers on 24330 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=27469 shrink_windows=True', 'datetime': '2023-05-20T23:27:58.231837', 'gensim': '4.3.1', 'python': '3.8.13 (default, Mar 28 2022, 11:38:47) \n[GCC 7.5.0]', 'platform': 'Linux-5.19.0-41-generic-x86_64-with-glibc2.17', 'event': 'train'}
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 0.79% examples, 185109 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 1.73% examples, 189835 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 2.60% examples, 195081 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 3.34% examples, 191892 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 4.13% examples, 191969 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 5.03% examples, 195518 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at
words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 88.99% examples, 148983 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 89.50% examples, 148809 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 90.10% examples, 148714 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 90.42% examples, 148169 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 90.84% examples, 147867 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 91.32% examples, 147572 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 91.73% examples, 147300 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 92.25% examples, 147085 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 92.60% examples, 146693 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 93.27% examples, 146510 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 93.62% examples, 146088 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 93.97% examples, 145676 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 94.47% examples, 145326 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 94.89% examples, 145072 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 95.42% examples, 144905 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 95.93% examples, 144813 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 96.34% examples, 144516 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 96.56% examples, 144011 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 97.02% examples, 143761 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 97.51% examples, 143575 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 98.06% examples, 143454 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 98.58% examples, 143327 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 99.23% examples, 143327 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 99.75% examples, 143130 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 100.00% examples, 142648 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.word2vec:EPOCH 4: training on 25000095 raw words (24838800 effective words) took 174.1s, 142647 effective words/s
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'training on 125000475 raw words (124193726 effective words) took 884.6s, 140393 effective words/s', 'datetime': '2023-05-20T23:42:42.847993', 'gensim': '4.3.1', 'python': '3.8.13 (default, Mar 28 2022, 11:38:47) \n[GCC 7.5.0]', 'platform': 'Linux-5.19.0-41-generic-x86_64-with-glibc2.17', 'event': 'train'}
# INFO:gensim.utils:Word2Vec lifecycle event {'params': 'Word2Vec<vocab=24330, vector_size=100, alpha=0.025>', 'datetime': '2023-05-20T23:42:42.848673', 'gensim': '4.3.1', 'python': '3.8.13 (default, Mar 28 2022, 11:38:47) \n[GCC 7.5.0]', 'platform': 'Linux-5.19.0-41-generic-x86_64-with-glibc2.17', 'event': 'created'}
# INFO:gensim.utils:Word2Vec lifecycle event {'fname_or_handle': '../outputs/movie_rec_2023-05-20 23:42:42.849724_cbow_epoch5', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2023-05-20T23:42:42.849755', 'gensim': '4.3.1', 'python': '3.8.13 (default, Mar 28 2022, 11:38:47) \n[GCC 7.5.0]', 'platform': 'Linux-5.19.0-41-generic-x86_64-with-glibc2.17', 'event': 'saving'}
# INFO:gensim.utils:not storing attribute cum_table
# INFO:gensim.utils:saved ../outputs/movie_rec_2023-05-20 23:42:42.849724_cbow_epoch5
# training time = 0:14:49.034797

# %%
df_movies = pd.read_csv(f'{data_path}/movies.csv')
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
def get_movie_name(movieId):
    return df_movies[df_movies['movieId']==movieId]['title'].iloc[0]

def get_recom(movieIds, model):
    for movideId in movieIds:
        recs = model.wv.most_similar(movideId, topn=10)
        query = get_movie_name(movideId)
        results = [(get_movie_name(rec[0]), rec[0], rec[1]) for rec in recs]

        print(f'query movie: {query}({movideId})\nresults (top {len(results)}):')
        for i, result in enumerate(results):
            print(f'{i}. {result[0]} (movieId={result[1]}, confidence={result[2]})')

def get_recom_by_name(movie_name, model):
    query_id = df_movies[df_movies['title'].str.contains(f'(?i){movie_name}')]['movieId'].iloc[0]
    get_recom([query_id], model)

# %%
from gensim.models import Word2Vec

model_1 = Word2Vec.load(f'{output_path}/movie_rec_2023-05-20 03:12:43.294816')
model_2 = Word2Vec.load(f'{output_path}/movie_rec_2023-05-20 19:21:56.098519_epoch15')
model_cbow = Word2Vec.load(f'{output_path}/movie_rec_2023-05-20 23:42:42.849724_cbow_epoch5')
# Out:
# INFO:gensim.utils:loading Word2Vec object from ../outputs/movie_rec_2023-05-20 03:12:43.294816
# INFO:gensim.utils:loading wv recursively from ../outputs/movie_rec_2023-05-20 03:12:43.294816.wv.* with mmap=None
# INFO:gensim.utils:setting ignored attribute cum_table to None
# INFO:gensim.utils:Word2Vec lifecycle event {'fname': '../outputs/movie_rec_2023-05-20 03:12:43.294816', 'datetime': '2023-05-20T23:46:59.573997', 'gensim': '4.3.1', 'python': '3.8.13 (default, Mar 28 2022, 11:38:47) \n[GCC 7.5.0]', 'platform': 'Linux-5.19.0-41-generic-x86_64-with-glibc2.17', 'event': 'loaded'}
# INFO:gensim.utils:loading Word2Vec object from ../outputs/movie_rec_2023-05-20 19:21:56.098519_epoch15
# INFO:gensim.utils:loading wv recursively from ../outputs/movie_rec_2023-05-20 19:21:56.098519_epoch15.wv.* with mmap=None
# INFO:gensim.utils:setting ignored attribute cum_table to None
# INFO:gensim.utils:Word2Vec lifecycle event {'fname': '../outputs/movie_rec_2023-05-20 19:21:56.098519_epoch15', 'datetime': '2023-05-20T23:46:59.741933', 'gensim': '4.3.1', 'python': '3.8.13 (default, Mar 28 2022, 11:38:47) \n[GCC 7.5.0]', 'platform': 'Linux-5.19.0-41-generic-x86_64-with-glibc2.17', 'event': 'loaded'}
# INFO:gensim.utils:loading Word2Vec object from ../outputs/movie_rec_2023-05-20 23:42:42.849724_cbow_epoch5
# INFO:gensim.utils:loading wv recursively from ../outputs/movie_rec_2023-05-20 23:42:42.849724_cbow_epoch5.wv.* with mmap=None
# INFO:gensim.utils:setting ignored attribute cum_table to None
# INFO:gensim.utils:Word2Vec lifecycle event {'fname': '../outputs/movie_rec_2023-05-20 23:42:42.849724_cbow_epoch5', 'datetime': '2023-05-20T23:46:59.893054', 'gensim': '4.3.1', 'python': '3.8.13 (default, Mar 28 2022, 11:38:47) \n[GCC 7.5.0]', 'platform': 'Linux-5.19.0-41-generic-x86_64-with-glibc2.17', 'event': 'loaded'}

# %%
num_queries = 20
count = 0

for row in df_movies[:100].iterrows():
    queryId = row[1]['movieId']
    # idx = model_1.wv.index2word(queryId)
    try:
        get_recom([queryId], model)
        count = count + 1
    except:
        print(f'{get_movie_name(queryId)}({queryId}) is not present in model')
    print('\n\n')
    if count > num_queries:
        break
# Out:
# query movie: Toy Story (1995)(1)
# results (top 5):
# 0. Braveheart (1995) (movieId=110, confidence=0.9528072476387024)
# 1. Star Wars: Episode IV - A New Hope (1977) (movieId=260, confidence=0.9519764184951782)
# 2. Twelve Monkeys (a.k.a. 12 Monkeys) (1995) (movieId=32, confidence=0.9381943941116333)
# 3. Forrest Gump (1994) (movieId=356, confidence=0.9331863522529602)
# 4. Lion King, The (1994) (movieId=364, confidence=0.9301167726516724)
#
#
#
# query movie: Jumanji (1995)(2)
# results (top 5):
# 0. Mask, The (1994) (movieId=367, confidence=0.9698435068130493)
# 1. Speed (1994) (movieId=377, confidence=0.9634350538253784)
# 2. Ace Ventura: When Nature Calls (1995) (movieId=19, confidence=0.9631405472755432)
# 3. Dumb & Dumber (Dumb and Dumber) (1994) (movieId=231, confidence=0.9625581502914429)
# 4. Batman Forever (1995) (movieId=153, confidence=0.9610676765441895)
#
#
#
# query movie: Grumpier Old Men (1995)(3)
# results (top 5):
# 0. Father of the Bride Part II (1995) (movieId=5, confidence=0.9781428575515747)
# 1. Multiplicity (1996) (movieId=719, confidence=0.9602203965187073)
# 2. Birdcage, The (1996) (movieId=141, confidence=0.9569083452224731)
# 3. Sabrina (1995) (movieId=7, confidence=0.9448937177658081)
# 4. Truth About Cats & Dogs, The (1996) (movieId=708, confidence=0.9405450224876404)
#
#
#
# query movie: Waiting to Exhale (1995)(4)
# results (top 5):
# 0. Corrina, Corrina (1994) (movieId=351, confidence=0.974608838558197)
# 1. How to Make an American Quilt (1995) (movieId=46, confidence=0.9624205827713013)
# 2. Boys on the Side (1995) (movieId=218, confidence=0.9616426229476929)
# 3. Something to Talk About (1995) (movieId=195, confidence=0.9563144445419312)
# 4. Speechless (1994) (movieId=378, confidence=0.9494632482528687)
#
#
#
# query movie: Father of the Bride Part II (1995)(5)
# results (top 5):
# 0. Grumpier Old Men (1995) (movieId=3, confidence=0.9781429171562195)
# 1. Multiplicity (1996) (movieId=719, confidence=0.9586909413337708)
# 2. Birdcage, The (1996) (movieId=141, confidence=0.9480460286140442)
# 3. Sgt. Bilko (1996) (movieId=637, confidence=0.9437139630317688)
# 4. Truth About Cats & Dogs, The (1996) (movieId=708, confidence=0.9382563233375549)
#
#
#
# query movie: Heat (1995)(6)
# results (top 5):
# 0. Twelve Monkeys (a.k.a. 12 Monkeys) (1995) (movieId=32, confidence=0.9591515064239502)
# 1. Casino (1995) (movieId=16, confidence=0.9388030171394348)
# 2. Leaving Las Vegas (1995) (movieId=25, confidence=0.9258766174316406)
# 3. Trainspotting (1996) (movieId=778, confidence=0.9136865139007568)
# 4. Fargo (1996) (movieId=608, confidence=0.9128590226173401)
#
#
#
# query movie: Sabrina (1995)(7)
# results (top 5):
# 0. Grumpier Old Men (1995) (movieId=3, confidence=0.9448937177658081)
# 1. Truth About Cats & Dogs, The (1996) (movieId=708, confidence=0.9383741617202759)
# 2. Mr. Holland's Opus (1995) (movieId=62, confidence=0.9293080568313599)
# 3. First Wives Club, The (1996) (movieId=830, confidence=0.9292033910751343)
# 4. Father of the Bride Part II (1995) (movieId=5, confidence=0.9280228614807129)
#
#
#
# query movie: Tom and Huck (1995)(8)
# results (top 5):
# 0. Kid in King Arthur's Court, A (1995) (movieId=258, confidence=0.9412539601325989)
# 1. Big Green, The (1995) (movieId=54, confidence=0.9326139092445374)
# 2. Far From Home: The Adventures of Yellow Dog (1995) (movieId=238, confidence=0.9226497411727905)
# 3. Andre (1994) (movieId=577, confidence=0.9206485748291016)
# 4. NeverEnding Story III, The (1994) (movieId=126, confidence=0.9122397899627686)
#
#
#
# query movie: Sudden Death (1995)(9)
# results (top 5):
# 0. Last Man Standing (1996) (movieId=996, confidence=0.9046766757965088)
# 1. Phantom, The (1996) (movieId=761, confidence=0.8922421932220459)
# 2. Money Train (1995) (movieId=20, confidence=0.8903603553771973)
# 3. Daylight (1996) (movieId=798, confidence=0.8889306783676147)
# 4. Chain Reaction (1996) (movieId=836, confidence=0.8885865807533264)
#
#
#
# query movie: GoldenEye (1995)(10)
# results (top 5):
# 0. Waterworld (1995) (movieId=208, confidence=0.9795858860015869)
# 1. Stargate (1994) (movieId=316, confidence=0.974781334400177)
# 2. Die Hard: With a Vengeance (1995) (movieId=165, confidence=0.9737398028373718)
# 3. True Lies (1994) (movieId=380, confidence=0.9708296060562134)
# 4. Cliffhanger (1993) (movieId=434, confidence=0.9658615589141846)
#
#
#
# query movie: American President, The (1995)(11)
# results (top 5):
# 0. Dave (1993) (movieId=440, confidence=0.9696921110153198)
# 1. Legends of the Fall (1994) (movieId=266, confidence=0.9462813138961792)
# 2. Mr. Holland's Opus (1995) (movieId=62, confidence=0.9446602463722229)
# 3. While You Were Sleeping (1995) (movieId=339, confidence=0.9405490159988403)
# 4. So I Married an Axe Murderer (1993) (movieId=543, confidence=0.9392897486686707)
#
#
#
# query movie: Dracula: Dead and Loving It (1995)(12)
# results (top 5):
# 0. Tales from the Crypt Presents: Bordello of Blood (1996) (movieId=842, confidence=0.9142937064170837)
# 1. Phantom, The (1996) (movieId=761, confidence=0.9134114384651184)
# 2. Halloween: The Curse of Michael Myers (Halloween 6: The Curse of Michael Myers) (1995) (movieId=891, confidence=0.9110754132270813)
# 3. Thinner (1996) (movieId=742, confidence=0.9109919667243958)
# 4. Down Periscope (1996) (movieId=135, confidence=0.8927959203720093)
#
#
#
# query movie: Balto (1995)(13)
# results (top 5):
# 0. Oliver & Company (1988) (movieId=709, confidence=0.9134740829467773)
# 1. Goofy Movie, A (1995) (movieId=239, confidence=0.9096751809120178)
# 2. Pagemaster, The (1994) (movieId=558, confidence=0.9052030444145203)
# 3. Swan Princess, The (1994) (movieId=313, confidence=0.8993412256240845)
# 4. Three Caballeros, The (1945) (movieId=1024, confidence=0.8871719241142273)
#
#
#
# query movie: Nixon (1995)(14)
# results (top 5):
# 0. City Hall (1996) (movieId=100, confidence=0.9411371946334839)
# 1. Mulholland Falls (1996) (movieId=707, confidence=0.9383096694946289)
# 2. Mighty Aphrodite (1995) (movieId=52, confidence=0.9105868339538574)
# 3. Juror, The (1996) (movieId=79, confidence=0.9069348573684692)
# 4. River Wild, The (1994) (movieId=376, confidence=0.903348982334137)
#
#
#
# query movie: Cutthroat Island (1995)(15)
# results (top 5):
# 0. Highlander III: The Sorcerer (a.k.a. Highlander: The Final Dimension) (1994) (movieId=405, confidence=0.9194871187210083)
# 1. Vampire in Brooklyn (1995) (movieId=93, confidence=0.9157823920249939)
# 2. Shadow, The (1994) (movieId=533, confidence=0.9101204872131348)
# 3. Bad Girls (1994) (movieId=416, confidence=0.9083963632583618)
# 4. Mary Shelley's Frankenstein (Frankenstein) (1994) (movieId=273, confidence=0.9002957344055176)
#
#
#
# query movie: Casino (1995)(16)
# results (top 5):
# 0. Carlito's Way (1993) (movieId=431, confidence=0.9390997886657715)
# 1. Heat (1995) (movieId=6, confidence=0.9388030767440796)
# 2. Philadelphia (1993) (movieId=508, confidence=0.9379411339759827)
# 3. True Romance (1993) (movieId=555, confidence=0.9329022765159607)
# 4. Léon: The Professional (a.k.a. The Professional) (Léon) (1994) (movieId=293, confidence=0.9276958703994751)
#
#
#
# query movie: Sense and Sensibility (1995)(17)
# results (top 5):
# 0. Dead Man Walking (1995) (movieId=36, confidence=0.9373767971992493)
# 1. Emma (1996) (movieId=838, confidence=0.9174906611442566)
# 2. Mr. Holland's Opus (1995) (movieId=62, confidence=0.9154738783836365)
# 3. Muriel's Wedding (1994) (movieId=342, confidence=0.9148119688034058)
# 4. Much Ado About Nothing (1993) (movieId=497, confidence=0.9114437103271484)
#
#
#
# query movie: Four Rooms (1995)(18)
# results (top 5):
# 0. Crash (1996) (movieId=1483, confidence=0.9143164753913879)
# 1. Kids (1995) (movieId=175, confidence=0.9055162072181702)
# 2. Frighteners, The (1996) (movieId=799, confidence=0.895674467086792)
# 3. Bound (1996) (movieId=866, confidence=0.8929094076156616)
# 4. Things to Do in Denver When You're Dead (1995) (movieId=81, confidence=0.8891355991363525)
#
#
#
# query movie: Ace Ventura: When Nature Calls (1995)(19)
# results (top 5):
# 0. Ace Ventura: Pet Detective (1994) (movieId=344, confidence=0.9822524189949036)
# 1. Dumb & Dumber (Dumb and Dumber) (1994) (movieId=231, confidence=0.9822378754615784)
# 2. Waterworld (1995) (movieId=208, confidence=0.9766873121261597)
# 3. Mask, The (1994) (movieId=367, confidence=0.9763168692588806)
# 4. Batman Forever (1995) (movieId=153, confidence=0.9696164131164551)
#
#
#
# query movie: Money Train (1995)(20)
# results (top 5):
# 0. Terminal Velocity (1994) (movieId=548, confidence=0.9488095641136169)
# 1. Assassins (1995) (movieId=23, confidence=0.9480970501899719)
# 2. Striking Distance (1993) (movieId=544, confidence=0.9477652311325073)
# 3. Virtuosity (1995) (movieId=338, confidence=0.9464517831802368)
# 4. Under Siege 2: Dark Territory (1995) (movieId=204, confidence=0.9384512901306152)
#
#
#
# query movie: Get Shorty (1995)(21)
# results (top 5):
# 0. Crimson Tide (1995) (movieId=161, confidence=0.9536855816841125)
# 1. Outbreak (1995) (movieId=292, confidence=0.9532961845397949)
# 2. Clear and Present Danger (1994) (movieId=349, confidence=0.9520928859710693)
# 3. In the Line of Fire (1993) (movieId=474, confidence=0.9487630724906921)
# 4. Net, The (1995) (movieId=185, confidence=0.9438181519508362)

# %%
movie_name = '1408'
print('recommendations by SG Model (5 epcohs)')
get_recom_by_name(movie_name, model_1)
print('\nrecommendations by SG Model (15 epcohs)')
get_recom_by_name(movie_name, model_2)
print('\nrecommendations by CBOW Model (5 epcohs)')
get_recom_by_name(movie_name, model_cbow)
# Out:
# recommendations by SG Model (5 epcohs)
# query movie: 1408 (2007)(53953)
# results (top 10):
# 0. Planet Terror (2007) (movieId=54995, confidence=0.9412971138954163)
# 1. Mist, The (2007) (movieId=56145, confidence=0.9394574165344238)
# 2. Death Proof (2007) (movieId=53519, confidence=0.9375334978103638)
# 3. Cloverfield (2008) (movieId=57368, confidence=0.930331826210022)
# 4. Hostel (2005) (movieId=42723, confidence=0.9293372631072998)
# 5. 28 Weeks Later (2007) (movieId=53000, confidence=0.9239894151687622)
# 6. Number 23, The (2007) (movieId=51086, confidence=0.9172055721282959)
# 7. 2012 (2009) (movieId=72378, confidence=0.9161345362663269)
# 8. Descent, The (2005) (movieId=40732, confidence=0.9110991954803467)
# 9. Terminator Salvation (2009) (movieId=68791, confidence=0.9097989797592163)
#
# recommendations by SG Model (15 epcohs)
# query movie: 1408 (2007)(53953)
# results (top 10):
# 0. Mist, The (2007) (movieId=56145, confidence=0.9493451714515686)
# 1. Hostel (2005) (movieId=42723, confidence=0.9463562965393066)
# 2. 28 Weeks Later (2007) (movieId=53000, confidence=0.9447047114372253)
# 3. Number 23, The (2007) (movieId=51086, confidence=0.9390504956245422)
# 4. Death Proof (2007) (movieId=53519, confidence=0.9339973330497742)
# 5. Planet Terror (2007) (movieId=54995, confidence=0.9308918714523315)
# 6. Cloverfield (2008) (movieId=57368, confidence=0.9282193183898926)
# 7. Descent, The (2005) (movieId=40732, confidence=0.9263837933540344)
# 8. Happening, The (2008) (movieId=60037, confidence=0.9091521501541138)
# 9. Zodiac (2007) (movieId=51540, confidence=0.9071725606918335)
#
# recommendations by CBOW Model (5 epcohs)
# query movie: 1408 (2007)(53953)
# results (top 10):
# 0. Mist, The (2007) (movieId=56145, confidence=0.5703109502792358)
# 1. Skeleton Key, The (2005) (movieId=34532, confidence=0.5190949440002441)
# 2. Vacancy (2007) (movieId=52644, confidence=0.5006696581840515)
# 3. Happening, The (2008) (movieId=60037, confidence=0.49022993445396423)
# 4. Conjuring, The (2013) (movieId=103688, confidence=0.48972541093826294)
# 5. Number 23, The (2007) (movieId=51086, confidence=0.486123263835907)
# 6. Jacket, The (2005) (movieId=27788, confidence=0.473192423582077)
# 7. Sinister (2012) (movieId=97188, confidence=0.46600401401519775)
# 8. Insidious: Chapter 2 (2013) (movieId=104908, confidence=0.4643564224243164)
# 9. Insidious (2010) (movieId=85788, confidence=0.4613998532295227)
